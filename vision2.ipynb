# %%
import cv2
import numpy as np
import time
import json
import urllib.request

cap = cv2.VideoCapture(0)

if (cap.isOpened() == False): 
    print("Unable to read camera feed")

turn_url = "http://pub.inspace.co.kr:10200/turn_status"
action_url = "http://pub.inspace.co.kr:10200/action?action_idx="
end_url =  "http://pub.inspace.co.kr:10200/periodic_status"

pts1 = np.float32([[220,255],[165, 350],[402,260],[420,360]])

pts2 = np.float32([[10,10],[10,290],[290,10],[290,290]])

M = cv2.getPerspectiveTransform(pts1, pts2)

x = [36,65,94,123,152,180,209,238,269]
y = [38, 68, 99, 126, 154, 182, 210, 238, 266]

while(1):

    end_response = urllib.request.urlopen(end_url)
    end_result = json.loads(end_response.read().decode('utf-8'))
    
    if end_result['win_index'] == 0 : #End Check
        is_End = False
        print("Not End!")
    else:
        print("End!")

    while not is_End:
        
        turn_response = urllib.request.urlopen(turn_url)
        turn_result = json.loads(turn_response.read().decode('utf-8'))

        if turn_result['curr_turn'] == turn_result['enemy_turn'] : #Turn Check
            # Not player turn
            print("Omok Turn!")
            time.sleep(1)

        else:
            print("Player Turn!")
            # Player turn
            is_Change = False

            # time delay or stable check

            ret, frame = cap.read()
            pre_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            pre_frame = cv2.warpPerspective(pre_frame, M, (300,300))
            cv2.imshow('pre_frame', pre_frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
                
            while not is_Change:
                frame_list = []

                is_Stable = False

                while not is_Stable:

                    ret, frame = cap.read()
                    cur_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                    grid_frame = cv2.warpPerspective(cur_frame, M, (300,300))
                    cur_frame = cv2.warpPerspective(cur_frame, M, (300,300))

                    if True :
                        cv2.circle(grid_frame, (36,38), 2, (255), -1)
                        cv2.circle(grid_frame, (65,38), 2, (255), -1)
                        cv2.circle(grid_frame, (94,38), 2, (255), -1)
                        cv2.circle(grid_frame, (123,38), 2, (255), -1)
                        cv2.circle(grid_frame, (152,38), 2, (255), -1)
                        cv2.circle(grid_frame, (180,38), 2, (255), -1)
                        cv2.circle(grid_frame, (209,38), 2, (255), -1)
                        cv2.circle(grid_frame, (238,38), 2, (255), -1)
                        cv2.circle(grid_frame, (269,38), 2, (255), -1)

                        cv2.circle(grid_frame, (36,68), 2, (255), -1)
                        cv2.circle(grid_frame, (65,68), 2, (255), -1)
                        cv2.circle(grid_frame, (94,68), 2, (255), -1)
                        cv2.circle(grid_frame, (123,68), 2, (255), -1)
                        cv2.circle(grid_frame, (152,68), 2, (255), -1)
                        cv2.circle(grid_frame, (180,68), 2, (255), -1)
                        cv2.circle(grid_frame, (209,68), 2, (255), -1)
                        cv2.circle(grid_frame, (238,68), 2, (255), -1)
                        cv2.circle(grid_frame, (269,68), 2, (255), -1)

                        cv2.circle(grid_frame, (36,99), 2, (255), -1)
                        cv2.circle(grid_frame, (65,99), 2, (255), -1)
                        cv2.circle(grid_frame, (94,99), 2, (255), -1)
                        cv2.circle(grid_frame, (123,99), 2, (255), -1)
                        cv2.circle(grid_frame, (148,99), 2, (255), -1)
                        cv2.circle(grid_frame, (180,99), 2, (255), -1)
                        cv2.circle(grid_frame, (209,99), 2, (255), -1)
                        cv2.circle(grid_frame, (238,99), 2, (255), -1)
                        cv2.circle(grid_frame, (269,99), 2, (255), -1)
                        
                        cv2.circle(grid_frame, (36,126), 2, (255), -1)
                        cv2.circle(grid_frame, (64,126), 2, (255), -1)
                        cv2.circle(grid_frame, (95,126), 2, (255), -1)
                        cv2.circle(grid_frame, (123,126), 2, (255), -1)
                        cv2.circle(grid_frame, (148,126), 2, (255), -1)
                        cv2.circle(grid_frame, (180,126), 2, (255), -1)
                        cv2.circle(grid_frame, (209,126), 2, (255), -1)
                        cv2.circle(grid_frame, (238,126), 2, (255), -1)
                        cv2.circle(grid_frame, (269,126), 2, (255), -1)

                        cv2.circle(grid_frame, (36,154), 2, (255), -1)
                        cv2.circle(grid_frame, (64,154), 2, (255), -1)
                        cv2.circle(grid_frame, (95,154), 2, (255), -1)
                        cv2.circle(grid_frame, (123,154), 2, (255), -1)
                        cv2.circle(grid_frame, (148,154), 2, (255), -1)
                        cv2.circle(grid_frame, (180,154), 2, (255), -1)
                        cv2.circle(grid_frame, (209,154), 2, (255), -1)
                        cv2.circle(grid_frame, (238,154), 2, (255), -1)
                        cv2.circle(grid_frame, (269,154), 2, (255), -1)

                        cv2.circle(grid_frame, (36,182), 2, (255), -1)
                        cv2.circle(grid_frame, (64,182), 2, (255), -1)
                        cv2.circle(grid_frame, (95,182), 2, (255), -1)
                        cv2.circle(grid_frame, (123,182), 2, (255), -1)
                        cv2.circle(grid_frame, (148,182), 2, (255), -1)
                        cv2.circle(grid_frame, (180,182), 2, (255), -1)
                        cv2.circle(grid_frame, (209,182), 2, (255), -1)
                        cv2.circle(grid_frame, (238,182), 2, (255), -1)
                        cv2.circle(grid_frame, (269,182), 2, (255), -1)

                        cv2.circle(grid_frame, (36,210), 2, (255), -1)
                        cv2.circle(grid_frame, (64,210), 2, (255), -1)
                        cv2.circle(grid_frame, (95,210), 2, (255), -1)
                        cv2.circle(grid_frame, (123,210), 2, (255), -1)
                        cv2.circle(grid_frame, (148,210), 2, (255), -1)
                        cv2.circle(grid_frame, (180,210), 2, (255), -1)
                        cv2.circle(grid_frame, (209,210), 2, (255), -1)
                        cv2.circle(grid_frame, (238,210), 2, (255), -1)
                        cv2.circle(grid_frame, (269,210), 2, (255), -1)

                        cv2.circle(grid_frame, (36,238), 2, (255), -1)
                        cv2.circle(grid_frame, (64,238), 2, (255), -1)
                        cv2.circle(grid_frame, (95,238), 2, (255), -1)
                        cv2.circle(grid_frame, (123,238), 2, (255), -1)
                        cv2.circle(grid_frame, (148,238), 2, (255), -1)
                        cv2.circle(grid_frame, (180,238), 2, (255), -1)
                        cv2.circle(grid_frame, (209,238), 2, (255), -1)
                        cv2.circle(grid_frame, (238,238), 2, (255), -1)
                        cv2.circle(grid_frame, (269,238), 2, (255), -1)

                        cv2.circle(grid_frame, (36,266), 2, (255), -1)
                        cv2.circle(grid_frame, (64,266), 2, (255), -1)
                        cv2.circle(grid_frame, (95,266), 2, (255), -1)
                        cv2.circle(grid_frame, (123,266), 2, (255), -1)
                        cv2.circle(grid_frame, (148,266), 2, (255), -1)
                        cv2.circle(grid_frame, (180,266), 2, (255), -1)
                        cv2.circle(grid_frame, (209,266), 2, (255), -1)
                        cv2.circle(grid_frame, (238,266), 2, (255), -1)
                        cv2.circle(grid_frame, (269,266), 2, (255), -1)
                    
                    cv2.imshow('grid_frame', grid_frame)

                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                    
                    if ret == True :
                        cv2.imshow('cur_frame', cur_frame)
                        time.sleep(1)

                        if cv2.waitKey(1) & 0xFF == ord('q'):
                            break
                        if len(frame_list):
                            frame_list = np.append(frame_list,np.array([cur_frame]),axis=0)
                            cv2.imshow('cur_frame',cur_frame)
                            if cv2.waitKey(1) & 0xFF == ord('q'):
                                break
                        else:
                            frame_list = np.array([cur_frame])

                        if len(frame_list) == 5 :
                            
                            # Stable Check
                            if np.max(np.std(frame_list,axis=0)) < 10:
                                is_Stable = True
                                print('Stable!')

                            else:
                                print(np.max(np.std(frame_list,axis=0)))
                                frame_list = frame_list[1:]
                                print('Not Stable!')
                    else:
                        break
                # Change Check

                if np.max(cv2.absdiff(pre_frame,cur_frame)) > 100:
                    is_Change = True
                    check_frame = cv2.absdiff(pre_frame,frame_list[-1])
                    x_check_frame = np.argmax(np.sum(check_frame, axis=0))
                    y_check_frame = np.argmax(np.sum(check_frame, axis=1))
                    cv2.circle(check_frame, (x_check_frame,y_check_frame), 2, (255), -1)

                    cv2.imshow('check_frame', check_frame)
                    time.sleep(1)
                    if cv2.waitKey(1) & 0xFF == ord('q'):
                        break
                    
                    for i, _x in enumerate(x):
                        if _x+10 >= x_check_frame:
                            x_idx = i
                            break
                    for j, _y in enumerate(y):
                        if _y >= y_check_frame:
                            y_idx = j
                            break
                        
                    
                    output_idx = x_idx + 9*y_idx
                    print(x_idx, y_idx, output_idx)
                    action_response = urllib.request.urlopen(action_url + str(output_idx))
                    action_result = json.loads(action_response.read().decode('utf-8'))
                    

                    print('Change!')
                else:
                    print('Not Change!')
                    
        end_response = urllib.request.urlopen(end_url)
        end_result = json.loads(end_response.read().decode('utf-8'))            
        if end_result['win_index'] != 0 :
            is_End = False
# Out:
# Not End!
# Player Turn!
# 78.70857640689482
# Not Stable!
# 82.80579689852638
# Not Stable!
# 81.2241343444176
# Not Stable!
# 73.51027139114642
# Not Stable!
# 73.29010847310843
# Not Stable!
# 14.551975810864997
# Not Stable!
# 15.663971399361019
# Not Stable!
# Stable!
# 0 0 0
# Change!
# Player Turn!
# Stable!
# Not Change!
# 81.52938120702254
# Not Stable!
# 66.68912954897523
# Not Stable!
# 65.19999999999999
# Not Stable!
# 12.240914998479484
# Not Stable!
# 10.244998779892558
# Not Stable!
# Stable!
# 1 0 1
# Change!
# Player Turn!
# 69.92453074565464
# Not Stable!
# 68.34500713292815
# Not Stable!
# 68.2395779588356
# Not Stable!
# 68.45261134536797
# Not Stable!
# 22.030887408363743
# Not Stable!
# 19.548913013259842
# Not Stable!
# 10.047885349664377
# Not Stable!
# Stable!
# 4 4 40
# Change!
# Player Turn!
# 13.032267646115928
# Not Stable!
# Stable!
# Not Change!
# 69.43889400040874
# Not Stable!
# 16.728418933061185
# Not Stable!
# 11.586198686368192
# Not Stable!
# ...
